# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = 6 * np.random.rand(100,1) -3
Y = 0.5 * X**2 + 1.5 * X + 2 + np.random.rand(100,1)

# %%
# %matplotlib inline

# %%
plt.scatter(X, Y, color = 'g')
plt.xlabel("x dataset")
plt.ylabel("y dataset")
# Out:
# Text(0, 0.5, 'y dataset')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
predict = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
score = r2_score(Y_test,predict)
print(score)
# Out:
# 0.829484547299463

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 plt.plot(X_train, model.predict(X_train),color='g')
#       2 plt.scatter(X_train, Y_train)
#       3 plt.xlabel("x dataset")
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:269, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
#     267     check_is_fitted(self)
# --> 269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     270     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 1 features, but LinearRegression is expecting 4 features as input.

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=True)
x_train_poly = poly.fit_transform(X_train)
x_test_poly = poly.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train_poly, Y_train)
predict = model.predict(x_test_poly)
score = r2_score(Y_test,predict)
print(score)
# Out:
# 0.9895199143906601

# %%
print(model.coef_)
# Out:
# [[0.         1.47676262 0.48339372]]

# %%
plt.plot(X_train, model.predict(x_train_poly))
plt.scatter(X_train,Y_train)
plt.xlabel("x dataset")
plt.ylabel("y dataset")
# Out:
# Text(0, 0.5, 'y dataset')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3, include_bias=True)
x_train_poly = poly.fit_transform(X_train)
x_test_poly = poly.transform(X_test)

# %%
x_train_poly
# Out:
# array([[ 1.00000000e+00, -4.71154829e-01,  2.21986873e-01,
#         -1.04590187e-01],
#        [ 1.00000000e+00,  2.41472878e+00,  5.83091509e+00,
#          1.40800785e+01],
#        [ 1.00000000e+00,  2.36548381e+00,  5.59551363e+00,
#          1.32360969e+01],
#        [ 1.00000000e+00,  4.79973200e-01,  2.30374273e-01,
#          1.10573477e-01],
#        [ 1.00000000e+00, -3.43317991e-01,  1.17867243e-01,
#         -4.04659452e-02],
#        [ 1.00000000e+00,  1.61343816e+00,  2.60318270e+00,
#          4.20007430e+00],
#        [ 1.00000000e+00,  9.56462139e-02,  9.14819824e-03,
#          8.74990525e-04],
#        [ 1.00000000e+00, -5.18534814e-01,  2.68878353e-01,
#         -1.39422787e-01],
#        [ 1.00000000e+00,  6.20863585e-01,  3.85471591e-01,
#          2.39325274e-01],
#        [ 1.00000000e+00,  6.10644747e-01,  3.72887007e-01,
#          2.27701492e-01],
#        [ 1.00000000e+00,  2.48023048e-01,  6.15154322e-02,
#          1.52572450e-02],
#        [ 1.00000000e+00, -1.42720182e+00,  2.03690504e+00,
#         -2.90707458e+00],
#        [ 1.00000000e+00,  1.74713110e+00,  3.05246706e+00,
#          5.33306012e+00],
#        [ 1.00000000e+00,  2.70086556e+00,  7.29467480e+00,
#          1.97019360e+01],
#        [ 1.00000000e+00,  2.28928152e-01,  5.24080987e-02,
#          1.19976892e-02],
#        [ 1.00000000e+00,  9.68063504e-01,  9.37146948e-01,
#          9.07217759e-01],
#        [ 1.00000000e+00, -3.72661623e-01,  1.38876685e-01,
#         -5.17540109e-02],
#        [ 1.00000000e+00,  2.16170609e+00,  4.67297320e+00,
#          1.01015946e+01],
#        [ 1.00000000e+00, -2.91351763e+00,  8.48858500e+00,
#         -2.47316421e+01],
#        [ 1.00000000e+00,  2.23636610e+00,  5.00133333e+00,
#          1.11848123e+01],
#        [ 1.00000000e+00, -1.34662032e-01,  1.81338628e-02,
#         -2.44194281e-03],
#        [ 1.00000000e+00, -2.99663433e+00,  8.97981730e+00,
#         -2.69092288e+01],
#        [ 1.00000000e+00,  2.93012549e+00,  8.58563539e+00,
#          2.51569891e+01],
#        [ 1.00000000e+00,  1.03252961e+00,  1.06611740e+00,
#          1.10079778e+00],
#        [ 1.00000000e+00, -1.67223273e+00,  2.79636229e+00,
#         -4.67616854e+00],
#        [ 1.00000000e+00,  1.57804868e+00,  2.49023762e+00,
#          3.92971618e+00],
#        [ 1.00000000e+00, -2.13886483e+00,  4.57474276e+00,
#         -9.78475640e+00],
#        [ 1.00000000e+00,  6.50133602e-01,  4.22673701e-01,
#          2.74794376e-01],
#        [ 1.00000000e+00,  2.55828083e+00,  6.54480081e+00,
#          1.67434384e+01],
#        [ 1.00000000e+00,  2.49427997e+00,  6.22143256e+00,
#          1.55179946e+01],
#        [ 1.00000000e+00,  2.10611191e+00,  4.43570739e+00,
#          9.34209617e+00],
#        [ 1.00000000e+00,  2.78971210e+00,  7.78249358e+00,
#          2.17109165e+01],
#        [ 1.00000000e+00,  2.50304134e-01,  6.26521597e-02,
#          1.56820946e-02],
#        [ 1.00000000e+00,  2.28555160e+00,  5.22374613e+00,
#          1.19391413e+01],
#        [ 1.00000000e+00, -9.40617570e-01,  8.84761413e-01,
#         -8.32222130e-01],
#        [ 1.00000000e+00, -2.09818524e+00,  4.40238128e+00,
#         -9.23701140e+00],
#        [ 1.00000000e+00, -2.61252751e+00,  6.82530000e+00,
#         -1.78312840e+01],
#        [ 1.00000000e+00,  1.59418037e+00,  2.54141106e+00,
#          4.05146763e+00],
#        [ 1.00000000e+00,  7.72813973e-01,  5.97241438e-01,
#          4.61556529e-01],
#        [ 1.00000000e+00,  2.47193975e+00,  6.11048611e+00,
#          1.51047535e+01],
#        [ 1.00000000e+00,  2.78754781e+00,  7.77042278e+00,
#          2.16604250e+01],
#        [ 1.00000000e+00, -1.69769554e+00,  2.88217013e+00,
#         -4.89304737e+00],
#        [ 1.00000000e+00,  2.31781164e+00,  5.37225079e+00,
#          1.24518654e+01],
#        [ 1.00000000e+00, -2.13701145e+00,  4.56681795e+00,
#         -9.75934226e+00],
#        [ 1.00000000e+00, -1.76324784e+00,  3.10904295e+00,
#         -5.48201328e+00],
#        [ 1.00000000e+00, -1.24205568e-02,  1.54270231e-04,
#         -1.91612217e-06],
#        [ 1.00000000e+00, -1.86519817e+00,  3.47896422e+00,
#         -6.48895770e+00],
#        [ 1.00000000e+00, -1.17307549e+00,  1.37610611e+00,
#         -1.61427636e+00],
#        [ 1.00000000e+00, -2.54105122e+00,  6.45694130e+00,
#         -1.64074186e+01],
#        [ 1.00000000e+00, -2.08015621e+00,  4.32704987e+00,
#         -9.00093968e+00],
#        [ 1.00000000e+00, -2.65660818e+00,  7.05756701e+00,
#         -1.87491902e+01],
#        [ 1.00000000e+00,  1.82747160e+00,  3.33965243e+00,
#          6.10311996e+00],
#        [ 1.00000000e+00,  2.09827783e+00,  4.40276984e+00,
#          9.23823433e+00],
#        [ 1.00000000e+00,  3.92862485e-01,  1.54340932e-01,
#          6.06347623e-02],
#        [ 1.00000000e+00, -2.78015323e+00,  7.72925197e+00,
#         -2.14885048e+01],
#        [ 1.00000000e+00, -1.02819067e+00,  1.05717605e+00,
#         -1.08697855e+00],
#        [ 1.00000000e+00, -6.29220122e-01,  3.95917962e-01,
#         -2.49119548e-01],
#        [ 1.00000000e+00, -1.37737540e+00,  1.89716298e+00,
#         -2.61310562e+00],
#        [ 1.00000000e+00, -1.26305411e+00,  1.59530569e+00,
#         -2.01495741e+00],
#        [ 1.00000000e+00, -1.04556004e+00,  1.09319580e+00,
#         -1.14300184e+00],
#        [ 1.00000000e+00,  1.20151515e+00,  1.44363865e+00,
#          1.73455370e+00],
#        [ 1.00000000e+00,  1.37499213e-01,  1.89060335e-02,
#          2.59956473e-03],
#        [ 1.00000000e+00,  1.86485070e-02,  3.47766813e-04,
#          6.48533185e-06],
#        [ 1.00000000e+00, -1.69187965e+00,  2.86245675e+00,
#         -4.84293231e+00],
#        [ 1.00000000e+00,  2.51799671e-01,  6.34030744e-02,
#          1.59648733e-02],
#        [ 1.00000000e+00, -1.41317091e+00,  1.99705203e+00,
#         -2.82217584e+00],
#        [ 1.00000000e+00, -3.99097698e-01,  1.59278972e-01,
#         -6.35678712e-02]])

# %%
model = LinearRegression()
model.fit(x_train_poly, Y_train)
predict = model.predict(x_test_poly)
score = r2_score(Y_test,predict)
print(score)
# Out:
# 0.9894929856747913

# %%
plt.plot(X_train, model.predict(x_train_poly),"r-", linewidth = 2, label = "prediction")
plt.plot(X_train, Y_train,"b.", label='Training data')
plt.plot(X_test, Y_test,"g.", label='Testing data')
plt.xlabel("x dataset")
plt.ylabel("y dataset")
plt.legend()
plt.show()
